# %%
# !pip install camelot-py[cv] pandas

import camelot
import pandas as pd

pdf_path = "/content/january.pdf"
tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

final_tables = []
print(f"Found {len(tables)} tables in the PDF:")
for i, table in enumerate(tables):
    df = table.df
    print(f"\nTable {i+1} (Page {table.page}) - Shape: {df.shape}")
    print(df.head(3).to_string(index=False, header=False))
    keep = input("Keep this table? (y/n): ").strip().lower()
    if keep == 'y':
        final_tables.append(df)
        print(f"Added Table {i+1} to final output")
if final_tables:
    merged = pd.concat(final_tables, ignore_index=True)
    output_path = "/content/selected_tables.csv"
    merged.to_csv(output_path, index=False)
    print(f"✅ Selected tables saved to {output_path}")
else:
    print("⚠️ No tables were selected!")
# Out:
# ...
# WARNING: camelot-py 1.0.9 does not provide the extra 'cv'
# ...
# /usr/local/lib/python3.11/dist-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (55.053079999999994, 63.786739999999966, 572.7804399999993, 758.2002223529411)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# Found 14 tables in the PDF:
#
# Table 1 (Page 1) - Shape: (8, 2)
# Encouraging Start to 2025: Overall auto retail grew by 6.6% YoY, aligning with FADA’s earlier survey that
#                                                      anticipated a “flat to moderately positive” January.
#                                                                                Universal Category Growth:
# Keep this table? (y/n): n
#
# Table 2 (Page 2) - Shape: (41, 1)
#                                                                                    CIN U74140DL2004PNL130324
# ...
